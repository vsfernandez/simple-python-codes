# %%
import numpy as np 
import pandas as pd 
from numpy import array
from numpy import argmax

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = pd.read_csv(r'C:\Users\breast-w-699_im_numclass.csv',na_values='?')

# %%
from sklearn.model_selection import train_test_split
X= data.iloc[:,:-1]
y= data.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
#ANOVA F-Values feature selection for all features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
fvalue_selector = SelectKBest(f_classif, k='all')

# Apply the SelectKBest object to the features and target
X_kbest = fvalue_selector.fit_transform(X_train, y_train)

# %%
print('Original number of features:', X_train.shape[1])
print('Assessment per feature:',fvalue_selector.get_support())
# Out:
# Original number of features: 9
# Assessment per feature: [ True  True  True  True  True  True  True  True  True]

# %%
#original dataset with binary 1 and 0 target for visualization
df1 = pd.read_csv(r'C:\Users\Admin\Desktop\bai\AIS\2nd sem\INFO813 - Artificial Intelligence\Individual Assignment\breast-w-699_numclass.csv',na_values='?')

# %%
#correlation heat map of original dataset but target is converted to numeric
plt.figure(figsize=(12,11))
cor = df1.corr(method='pearson')
sns.heatmap(cor, annot=True, cmap=plt.cm.Oranges)
plt.show()

# %%
# Plot histograms for each variable
df1.hist(figsize = (15, 15))
plt.show()

# %%
#dataset imputed and smote and numeric 1/0 class
df2 = pd.read_csv(r'C:\Users\Admin\Desktop\bai\AIS\2nd sem\INFO813 - Artificial Intelligence\Individual Assignment\breast-w-699_im_sm_numclass.csv',na_values='?')

# %%
# Plot histograms for each variable
df2.hist(figsize = (15, 15))
plt.show()
